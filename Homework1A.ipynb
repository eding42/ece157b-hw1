# %% [markdown]
# # ECE 157B/272B Homework 1 Code
# Created by: Min Jian Yang and Matthew Dupree\
# Parts of the code are from:
# - The PyTorch tutorial: https://pytorch.org/tutorials/beginner/transformer_tutorial.html#load-and-batch-data
# - The KDnuggets tutorial: https://www.kdnuggets.com/2020/07/pytorch-lstm-text-generation-tutorial.html

# %% [markdown]
# ## Select a GPU Runtime
# * If you would like to complete this assignment on your own computer, make sure that your computer has a GPU compatible with PyTorch hardware acceleration. Without a GPU, training the models will take a very long time.
# * If you are using Google Colab, you will want to limit the amount of time you spend using a GPU runtime, to prevent running up against usage limits. If you are planning to train models this session, (i.e. beyond just vocabulary exploration,) you will need to select a GPU runtime by going to `Runtime` > `Change runtime type` > `Hardware accelerator` > `GPU`.
#     * For each model you intend to train and evaluate, you will need 10-15 minutes of GPU runtime, so plan in advance.
#     * If your computer goes to sleep or loses its internet connection for more than a minute or two, your Google Colab runtime will be recycled, erasing your model and training progress.

# %% [markdown]
# ## Install Libraries
# The below lab will check the versions of the PyTorch and Pandas libraries you have installed. We're expecting to see these versions of these packages, but later versions may also work fine.

# %%
# %pip install torch==2.1.2 scikit-learn==1.4.0 tokenizers==0.15.0
# Out:
# Requirement already satisfied: torch==2.1.2 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (2.1.2)
# Requirement already satisfied: scikit-learn==1.4.0 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (1.4.0)
# Requirement already satisfied: tokenizers==0.15.0 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (0.15.0)
# Requirement already satisfied: filelock in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (3.16.1)
# Requirement already satisfied: typing-extensions in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (4.12.2)
# Requirement already satisfied: sympy in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (1.13.1)
# Requirement already satisfied: networkx in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (3.4.2)
# Requirement already satisfied: jinja2 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (3.1.5)
# Requirement already satisfied: fsspec in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from torch==2.1.2) (2.1.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from scikit-learn==1.4.0) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from scikit-learn==1.4.0) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from scikit-learn==1.4.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from scikit-learn==1.4.0) (3.5.0)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from tokenizers==0.15.0) (0.27.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.2) (12.4.127)
# Requirement already satisfied: packaging>=20.9 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers==0.15.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers==0.15.0) (6.0.2)
# Requirement already satisfied: requests in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers==0.15.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers==0.15.0) (4.67.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from jinja2->torch==2.1.2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from sympy->torch==2.1.2) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers==0.15.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers==0.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers==0.15.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/eding/miniconda3/envs/157b/lib/python3.11/site-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers==0.15.0) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# You may be asked to restart the kernel after running the above cell. If so, please do so and then continue running the cells below. (This means specifically to "Restart" the _kernel_, not to get a new runtime, as that will remove the package versions installed.)

# %% [markdown]
# ## Import Libraries

# %%
from typing import List, Callable, Tuple, NamedTuple, Union, Optional, Type
from pathlib import Path

import math
import numpy as np

import torch
from torch import Tensor

from tokenizers import Tokenizer, models, pre_tokenizers, decoders, trainers, AddedToken, normalizers

from torch.nn import Module
from torch.nn import RNN, LSTM, GRU, Embedding, Linear
from torch.nn import CrossEntropyLoss

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Use GPU if available
# The below line checks if a CUDA environment (typically a GPU accelerator) is available. If so, we'll use it, otherwise we'll use the CPU.

# %%
DEVICE = 'cuda:0' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {DEVICE}')
# Out:
# Using device: cuda:0

# %% [markdown]
# ## Parameters to tune for your experiments
# The block below defines a "Parameters" class that you can use to configure settings for training runs of your various models. We will guide you through creating training functions that will make use of these parameters to allow you to create mostly-reusable code.
#
# We'll also define some global parameters that will be used across all of your models.

# %%
# Test set size as a fraction of the total dataset size
TEST_SIZE: float = 0.05

# Random seed for reproducibility
RANDOM_STATE: int = 42

# Vocabulary size - number of tokens to use to break up the text (and learn)
VOCAB_SIZE_CAP: int = 20000

# Minimum token frequency - tokens that appear less than this number of times will be ignored
# (So single-use complex words will be ignored)
MIN_TOKEN_FREQUENCY: int = 2
# If no tokens appear at least this many times, the vocabulary size will be reduced
# below VOCAB_SIZE

# %%
class Parameters(NamedTuple):
    ### Dataset and training parameters
    # How many different chunks of text to train on at the same time
    BATCH_SIZE: int
    # Token target -- how many tokens to backpropagate through at most
    BPTT: int
    # Learning rate
    LR: float
    # Number of epochs to train for
    EPOCHS: int

    ### Model parameters
    # Number of dimensions in the embedding of each token.
    #   More dimensions --> more meaning, but more computation
    EMBEDDING_DIM: int
    # Number of dimensions in the hidden state in the recurrent model
    HIDDEN_DIM: int
    # Number of hidden layers in the recurrent model
    NUM_LAYERS: int

# %% [markdown]
# ## Load Dataset

# %%
def load_data(path: Path) -> List[List[str]]:
    with open(path, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    def preprocess_line(line: str) -> str:
        # TODO: (optional) Do any preprocessing here
        #   e.g. removing punctuation, lowercasing, etc.
        # If a line is empty after preprocessing,
        # it will be removed from the dataset.
        return line
        
    # Each play is delineated by a line beginning '''
    # We can use this to split the data into plays,
    # then choose some of them to be training data
    # and some to be validation data
    plays = []
    current_play = []
    for line in lines:
        if line.startswith('\'\'\'') and current_play:
            plays.append(current_play)
            current_play = []

        processed_line = preprocess_line(line)
        if processed_line:
            current_play.append(processed_line)

    if current_play:
        # The last play won't be added in the loop
        plays.append(current_play)
    
    return plays


data_path = Path('shakespeare.txt')
data_list = load_data(data_path)

# %% [markdown]
# ## Split Dataset

# %%
def split_data(all_plays: List[List[str]]) -> Tuple[List[str], List[str]]:
    # We use the scikit-learn train_test_split function
    # just like we did in previous assignments.
    # As we only provide one list, it splits that list
    # into two pieces, one as TEST_SIZE fraction of the total data
    # and the other as the rest.
    training_plays, validation_plays = train_test_split(
        all_plays,
        test_size=TEST_SIZE,
        random_state=RANDOM_STATE,
    )

    # We'll append the plays in each set together into one big list of lines
    training_list = [line for play in training_plays for line in play]
    validation_list = [line for play in validation_plays for line in play]

    return training_list, validation_list

training_list, validation_list = split_data(data_list)

# %% [markdown]
# ## Prepare the dataset for training
#
# ### Build vocabulary
#
# * Break the given text into "tokens" using the tokenizer provided by the `tokenizers` library.
# * Build a vocabulary of tokens from the training set.

# %%
# We'll create a "WordPiece" tokenizer -- this is the kind used by BERT.
tokenizer = Tokenizer(models.WordPiece(unk_token="<unk>"))

# This sequence of normalizers is the same as the one used by BERT.
#  NFD: Normalization Form D (canonical decomposition)
#       This is fancy Unicode speak for transforming accented characters
#       into their base form and the accent separately.
#       e.g. é -> e + ´
#  Lowercase: Lowercase the text
#  StripAccents: Remove the accents from the text (e.g. ´ from é)
tokenizer.normalizer = normalizers.Sequence(
    [normalizers.NFD(), normalizers.Lowercase(), normalizers.StripAccents()]
)

# We'll use a whitespace pre-tokenizer.
# This will split the text on whitespace and punctuation first,
# then tokenize the words separately using the WordPiece model.
# That way, we can keep punctuation as separate tokens,
# which might be useful for the model.
tokenizer.pre_tokenizer = pre_tokenizers.Whitespace()
# pre_tokenizers.WhitespaceSplit() would also work here,
# but it would keep punctuation attached to words,
# which might not be what we want.

# Finally, we'll use the WordPiece decoder
# to convert the tokens back into text.
tokenizer.decoder = decoders.WordPiece()

# We'll train the tokenizer on the training data.
# You can play with the VOCAB_SIZE and MIN_TOKEN_FREQUENCY
# parameters to see how they affect the tokenizer.
trainer = trainers.WordPieceTrainer(
    vocab_size=VOCAB_SIZE_CAP,
    min_frequency=MIN_TOKEN_FREQUENCY,
    special_tokens=["<unk>"],
    show_progress=True,
)

# This training process isn't so bad for Shakespeare,
# but it can take a while for larger datasets scraped from the web.
tokenizer.train_from_iterator(training_list, trainer=trainer)

# Finally, we add a newline token to the tokenizer
# so that the model can learn to predict line breaks
# (and thus line lengths) instead of smushing it all
# together into one giant line with character names
# and stage directions and everything.
print("Newline added:",tokenizer.add_tokens([AddedToken("\n", normalized=False)]))
# Out:
# Newline added: 1

# %%
# create tokenizer and vocabulary
vocab_size = tokenizer.get_vocab_size()
print(f"The vocabulary size is {vocab_size}.")

# # uncomment to see the long list of vocabulary and corresponding integer IDs
tokenizer.get_vocab()
# Out:
# The vocabulary size is 19864.
# {'##mith': 8008,
#  'villages': 12896,
#  'oppress': 4593,
#  '##tock': 7779,
#  'tortured': 12017,
#  'marrying': 8152,
#  'shadowy': 18261,
#  'elf': 12802,
#  'all': 222,
#  'defunct': 14851,
#  '##iences': 8012,
#  'ham': 378,
#  'achieved': 7521,
#  'indirect': 6576,
#  'volume': 8917,
#  'pieces': 4398,
#  'spartan': 19311,
#  '##ater': 1696,
#  '##fect': 2090,
#  'eros': 2850,
#  '##bles': 3989,
#  'ebb': 6326,
#  'calling': 6759,
#  'dainties': 15703,
#  'sepulchre': 9173,
#  'confessions': 14905,
#  '##ied': 666,
#  'harry': 2872,
#  'western': 9703,
#  'bequeathed': 12151,
#  'infl': 5942,
#  '##riv': 16743,
#  'ought': 5600,
#  'pursuivant': 10367,
#  'between': 1619,
#  'contentious': 17758,
#  'kath': 627,
#  'three': 1109,
#  'instigation': 14799,
#  'susp': 4450,
#  '##icate': 4096,
#  'infirm': 5556,
#  'directions': 10894,
#  'treas': 8142,
#  'ball': 4082,
#  'robbers': 12080,
#  'presumptuous': 13651,
#  '##ematic': 14311,
#  'disord': 6385,
#  '##ues': 1504,
#  '##lose': 12777,
#  'strikest': 12953,
#  'daffodils': 19229,
#  '##beline': 1236,
#  'leavening': 19241,
#  'piece': 2632,
#  'sess': 7695,
#  'glasses': 9566,
#  'entr': 5809,
#  'harrow': 19542,
#  'unroll': 16888,
#  'refined': 15072,
#  'undistinguishable': 19610,
#  'conduct': 3792,
#  'hi': 602,
#  'menelaus': 4831,
#  'extremely': 12150,
#  'some': 411,
#  'patent': 12876,
#  'unright': 16883,
#  '##akers': 8415,
#  'lived': 3027,
#  'battery': 7932,
#  'inter': 2037,
#  '##izel': 1631,
#  '##ment': 710,
#  'q': 38,
#  'sibyl': 15913,
#  'genius': 11289,
#  'much': 541,
#  'preferred': 15291,
#  'shards': 16550,
#  'quickens': 17356,
#  'prings': 16584,
#  'vanishes': 18784,
#  'doncaster': 19613,
#  'obligation': 11106,
#  'doll': 16640,
#  'romans': 3669,
#  'unbruised': 12277,
#  'secondary': 17073,
#  'complexion': 4399,
#  'nav': 6013,
#  'rightly': 5800,
#  '##eness': 2072,
#  'cornelius': 2906,
#  'antig': 2322,
#  'discharge': 5452,
#  'instantly': 5572,
#  '##erre': 12495,
#  'brains': 4206,
#  'committed': 4793,
#  'tues': 10459,
#  'groat': 11773,
#  'tast': 12432,
#  'hybla': 18590,
#  'spared': 10624,
#  'petty': 5061,
#  'friend': 579,
#  'biondello': 2181,
#  'undertake': 4079,
#  'curiosity': 13535,
#  'mand': 12389,
#  'before': 662,
#  'round': 2760,
#  'presses': 13305,
#  'mercutio': 1376,
#  '##mast': 14008,
#  'resumes': 17424,
#  'flinty': 9700,
#  'bolingbroke': 879,
#  'tyranny': 5047,
#  'oftentimes': 10793,
#  'dilem': 19705,
#  'fenton': 2343,
#  'surgeon': 7232,
#  'chief': 3810,
#  'fantastical': 7937,
#  '##odes': 8571,
#  'humbled': 8915,
#  'blacker': 11817,
#  'remembers': 12963,
#  'bour': 4734,
#  'evils': 5662,
#  'dotard': 15307,
#  'disorders': 15557,
#  'foix': 16956,
#  'proper': 3222,
#  'snapper': 17805,
#  'stoops': 11447,
#  'ewer': 15659,
#  'profiting': 18336,
#  'dedicated': 18947,
#  'embracing': 11194,
#  'hips': 12371,
#  'freeze': 8530,
#  'clamber': 15518,
#  '##ipher': 10291,
#  'mighty': 2494,
#  'eyeball': 11711,
#  'notion': 16591,
#  'melteth': 18359,
#  'scarecrow': 19686,
#  'hap': 3156,
#  'entreaty': 8197,
#  'dolphin': 10160,
#  'fixture': 16105,
#  '##chas': 3849,
#  '##lets': 8848,
#  '##fare': 14058,
#  'vil': 10463,
#  'monuments': 12839,
#  'cradles': 19602,
#  'quenched': 18595,
#  'vac': 8346,
#  'capital': 7899,
#  'charm': 1792,
#  'matrons': 15568,
#  'comed': 16779,
#  'chance': 2243,
#  'tumble': 11090,
#  'thunderbol': 10169,
#  'thrives': 13191,
#  'nonce': 15393,
#  '##pse': 6699,
#  'rock': 4566,
#  'decl': 4358,
#  'bevis': 6517,
#  'winters': 9440,
#  '##oss': 2185,
#  '##mes': 16305,
#  'consec': 8063,
#  'cords': 7837,
#  'clouded': 15085,
#  'marig': 16732,
#  '##perance': 12745,
#  'firk': 16811,
#  'embolden': 19640,
#  'sheer': 16793,
#  'pulpit': 11099,
#  '##uten': 3373,
#  'spout': 10622,
#  'slime': 11638,
#  'songs': 7579,
#  'concave': 18225,
#  '##rench': 16366,
#  'speech': 2066,
#  '##icester': 12571,
#  'vex': 3829,
#  'mum': 6334,
#  'banner': 11741,
#  'thinks': 3615,
#  '##atiate': 14090,
#  'malefactors': 19523,
#  '##imely': 6797,
#  'nighting': 7788,
#  'resembled': 18886,
#  'convented': 15463,
#  'grandpre': 5822,
#  'warbling': 17208,
#  'tried': 6093,
#  '##rid': 5064,
#  'und': 740,
#  'heal': 6703,
#  'conjunctive': 19514,
#  'sheathe': 10307,
#  'complement': 17287,
#  'sextus': 15422,
#  'voluble': 12879,
#  'shut': 3474,
#  'swart': 14383,
#  'reporting': 17788,
#  'fronts': 15396,
#  'erg': 11623,
#  'hab': 3263,
#  '##arries': 16603,
#  'trimm': 9088,
#  'drawn': 2867,
#  'pestil': 6162,
#  'bristle': 13744,
#  'chink': 11481,
#  'movest': 14324,
#  'little': 945,
#  'strutting': 19258,
#  'injury': 5233,
#  'bounden': 17697,
#  'intercession': 11240,
#  'died': 2645,
#  'mellow': 10333,
#  'forget': 2705,
#  'ago': 5187,
#  'snowball': 18465,
#  '##adne': 14184,
#  '##come': 920,
#  'save': 1739,
#  'disqu': 11579,
#  'pocket': 4601,
#  '##inor': 3407,
#  'eyel': 8103,
#  'headlong': 10701,
#  '##anish': 8367,
#  '##bit': 6698,
#  'restraint': 7922,
#  'sembl': 5139,
#  '##lls': 12508,
#  'claps': 10569,
#  'safer': 7044,
#  'indifferently': 12146,
#  'guile': 10682,
#  'occurr': 18024,
#  'seeing': 3768,
#  'logic': 19099,
#  'measuring': 15461,
#  'mount': 2273,
#  'kentish': 14691,
#  'liable': 9855,
#  'meads': 11439,
#  'teems': 19116,
#  'frenchman': 4435,
#  '##iver': 6024,
#  'cornwall': 2255,
#  'horses': 3587,
#  'enkind': 11474,
#  'answer': 1009,
#  'garlands': 9633,
#  '##bane': 16399,
#  'aby': 17104,
#  '##pore': 11383,
#  'appell': 10012,
#  'grated': 17594,
#  'irishman': 18999,
#  'allure': 12619,
#  'rind': 16200,
#  '##fort': 1410,
#  'delabreth': 17787,
#  'lorraine': 17682,
#  '##onius': 1033,
#  '##res': 4618,
#  'unjustly': 10276,
#  'practis': 18043,
#  'determine': 5694,
#  'ray': 12421,
#  'parti': 17189,
#  'sealing': 15043,
#  'comfortable': 7832,
#  'tubal': 5846,
#  '##gre': 6501,
#  'purs': 3778,
#  'disprove': 15724,
#  'venison': 10788,
#  'intercepted': 13676,
#  'blank': 6546,
#  'pleading': 11985,
#  '##watch': 16280,
#  '##ria': 3151,
#  'brother': 751,
#  'cradle': 7199,
#  '##ellows': 9864,
#  'sensual': 13288,
#  'patrimony': 13674,
#  'fortune': 1248,
#  'que': 308,
#  'quintus': 4531,
#  'apace': 5410,
#  '##ford': 1706,
#  'peremptory': 7960,
#  '##esy': 8364,
#  '##ceives': 6273,
#  'ax': 5352,
#  'pities': 10883,
#  'chased': 8802,
#  'distrust': 10084,
#  'discomf': 11154,
#  'adopted': 12198,
#  'basest': 8242,
#  '##ceive': 1605,
#  'arr': 3317,
#  '##cceed': 5613,
#  '##orum': 14078,
#  'remuneration': 7957,
#  'conjured': 9572,
#  'fet': 6674,
#  'sper': 16964,
#  'professions': 15145,
#  'ercharged': 17184,
#  'protected': 18070,
#  'reviving': 18634,
#  'nurture': 19233,
#  '##anate': 16453,
#  'rational': 19734,
#  'melting': 11004,
#  'helps': 6968,
#  'divulged': 15894,
#  'aeac': 17816,
#  'assaulted': 18809,
#  'weight': 3546,
#  'compassing': 15240,
#  'upr': 14316,
#  'vouchers': 18139,
#  '##ulph': 1895,
#  'abstract': 11168,
#  'rook': 11327,
#  'chastity': 5983,
#  'buckets': 17209,
#  'argues': 8576,
#  'deprive': 17663,
#  '##enz': 1592,
#  'millstones': 18523,
#  'detests': 18864,
#  'wheres': 8371,
#  'withhold': 8036,
#  'metamorph': 14828,
#  'captivate': 19501,
#  'fleeting': 15454,
#  '##ona': 916,
#  'fab': 2174,
#  '##llor': 3570,
#  'gainst': 2890,
#  'stafford': 6637,
#  'cum': 12343,
#  'distaste': 13019,
#  'tatter': 9769,
#  'untie': 10858,
#  'thatch': 14158,
#  'rio': 16198,
#  'exist': 14286,
#  '##ct': 223,
#  '##urnish': 9360,
#  'lass': 8730,
#  'cambio': 9999,
#  '##ocal': 17884,
#  'helic': 2067,
#  'veil': 9004,
#  'hated': 5256,
#  'inkle': 18498,
#  'more': 315,
#  'quest': 1896,
#  '##cess': 2287,
#  'shows': 2685,
#  'wealth': 2985,
#  'engender': 10006,
#  'task': 4669,
#  'sorely': 11996,
#  'iron': 3799,
#  'rascals': 6631,
#  'catching': 8587,
#  '##bric': 10748,
#  'oaken': 16185,
#  'unheedful': 19690,
#  'easily': 5039,
#  'criedst': 18249,
#  '##asions': 6362,
#  'surges': 11727,
#  '##uel': 12586,
#  'traders': 13558,
#  '##iot': 4412,
#  'precept': 8903,
#  'accepts': 18447,
#  'load': 4994,
#  'loves': 1806,
#  'fort': 834,
#  'suffer': 2069,
#  'castle': 3014,
#  '##oubt': 6508,
#  '##venal': 10653,
#  'tool': 11401,
#  'ad': 395,
#  '##iant': 1936,
#  'abilities': 11597,
#  'report': 1913,
#  'noises': 12518,
#  'hole': 4854,
#  '##stood': 7407,
#  'pandulph': 1900,
#  '##racious': 8397,
#  '##xy': 16389,
#  '##uate': 6909,
#  'undeserved': 13702,
#  'cheat': 11792,
#  'plood': 16922,
#  'perdurable': 17797,
#  'flattery': 5817,
#  'pertinent': 19068,
#  'pratest': 15604,
#  'tied': 4744,
#  'sire': 7438,
#  'sicilius': 4122,
#  'twit': 17033,
#  'banditti': 11071,
#  'antio': 2620,
#  'encompassed': 19423,
#  '##ip': 536,
#  'faith': 989,
#  'brats': 14333,
#  'circle': 7287,
#  'thyself': 1790,
#  'used': 3217,
#  'ease': 3598,
#  '##m': 53,
#  'again': 455,
#  'witness': 2234,
#  'wholesome': 4751,
#  'dissever': 14463,
#  '##ool': 2763,
#  'b': 23,
#  'autolycus': 1326,
#  'lying': 4969,
#  '##oneys': 8830,
#  '##itaph': 6802,
#  'outsw': 14434,
#  'verbal': 15763,
#  'manner': 2835,
#  'vehemency': 15962,
#  'canakin': 16874,
#  'lena': 19172,
#  'monumental': 15318,
#  'smiles': 4272,
#  'excel': 11500,
#  'behoves': 12889,
#  'frosty': 9112,
#  'guise': 14574,
#  'rejoicing': 12062,
#  'void': 8171,
#  'assurance': 5310,
#  'app': 936,
#  'pit': 2300,
#  'franc': 1873,
#  '##nest': 14027,
#  'mistaken': 8862,
#  'perch': 11545,
#  'link': 9752,
#  'sicken': 11768,
#  'drach': 14701,
#  '##ges': 2158,
#  'fraughtage': 19004,
#  'honours': 3245,
#  'preced': 5796,
#  'denial': 8521,
#  'conclud': 5696,
#  'ungent': 7069,
#  'stream': 4936,
#  'neg': 3714,
#  'commoner': 6272,
#  'terror': 5108,
#  'sequ': 6210,
#  'trun': 8416,
#  'slubber': 17220,
#  'abhorred': 8638,
#  'cran': 1998,
#  'disjoin': 17068,
#  'leash': 12591,
#  'madmen': 8446,
#  'smart': 7802,
#  'crown': 1332,
#  'hangers': 14766,
#  'hud': 16121,
#  'biding': 17440,
#  'allowed': 9582,
#  'chime': 16717,
#  'jaw': 17529,
#  'bog': 14390,
#  'thickest': 15301,
#  'fillip': 18002,
#  'assemblies': 18622,
#  'reconcil': 13524,
#  'shog': 16543,
#  'barricado': 19661,
#  'contrived': 8121,
#  'woo': 1929,
#  '##asure': 1908,
#  '##less': 968,
#  'hym': 3751,
#  'ion': 16130,
#  '##lies': 16292,
#  'sampler': 19736,
#  'bloody': 1768,
#  'glories': 8833,
#  'deform': 6046,
#  'nobleman': 7489,
#  '##cious': 1409,
#  'winnow': 12933,
#  'benison': 14581,
#  'ripest': 18822,
#  'softly': 5682,
#  'magician': 12166,
#  'trinculo': 2247,
#  'foundation': 11766,
#  'grumio': 1709,
#  'shrug': 13709,
#  'gamesome': 15862,
#  'strong': 1565,
#  'vouchs': 3668,
#  '##rain': 8789,
#  'triumphs': 9052,
#  'sky': 4317,
#  'ster': 8745,
#  'meritorious': 16039,
#  'mechanical': 15742,
#  'greeks': 5449,
#  'chaps': 11482,
#  'abel': 17105,
#  '##cul': 3542,
#  'wade': 16256,
#  'commencement': 19314,
#  'hebrew': 15929,
#  'sew': 7736,
#  'sovereign': 2007,
#  'jig': 8727,
#  'unbound': 15222,
#  'blessedly': 18147,
#  'separated': 19146,
#  'butcher': 5173,
#  'exclaims': 11130,
#  'disbursed': 15842,
#  '##bread': 16398,
#  'thyme': 16738,
#  'furnish': 4796,
#  'unvalued': 16892,
#  'harping': 17629,
#  'caparisoned': 19388,
#  'herein': 5510,
#  'shroud': 6641,
#  'member': 8597,
#  'done': 767,
#  'geld': 8237,
#  'pag': 9209,
#  'ol': 12398,
#  'motives': 13113,
#  'desirest': 12218,
#  'importunes': 13188,
#  'myself': 839,
#  'bonds': 5820,
#  'jaquenetta': 4381,
#  'indifferent': 6166,
#  'consult': 11738,
#  '##itting': 12545,
#  'figo': 16101,
#  'dazz': 11276,
#  'inve': 16513,
#  'cy': 3882,
#  'stripling': 19207,
#  'pawn': 5085,
#  '##ner': 1493,
#  'attent': 10004,
#  '##icero': 5994,
#  'pointed': 10099,
#  'katarina': 13804,
#  'poss': 1869,
#  'germans': 13472,
#  'isle': 4246,
#  'emperial': 17963,
#  'constancy': 7517,
#  'aurora': 19533,
#  'invention': 5704,
#  'millions': 10247,
#  'mutter': 15049,
#  'current': 5707,
#  'dismember': 15131,
#  'surfeiting': 15508,
#  'ack': 5595,
#  '##unctions': 16729,
#  'aumerle': 2371,
#  'heads': 2568,
#  'marquis': 14272,
#  'crossing': 11888,
#  'err': 5090,
#  'tithing': 19554,
#  'hawthorn': 11117,
#  'hares': 12988,
#  'townsman': 12082,
#  'jolly': 8846,
#  'meditations': 13526,
#  'lys': 1205,
#  'witted': 8492,
#  'dry': 3399,
#  'predecess': 13796,
#  'bewitched': 19165,
#  'floods': 8620,
#  'dissuaded': 19283,
#  'volumnius': 7818,
#  'violets': 9418,
#  'unhatch': 18086,
#  'gone': 1007,
#  'drug': 11589,
#  'gagged': 19709,
#  'misconst': 12263,
#  'charitable': 6570,
#  '##anes': 7402,
#  'conceive': 5506,
#  'celebrate': 11158,
#  'kn': 242,
#  'homes': 18641,
#  'traffic': 8696,
#  'coun': 502,
#  'daws': 10424,
#  'commiseration': 14550,
#  'fastened': 18997,
#  'ab': 486,
#  '##spoke': 17248,
#  'hereto': 16678,
#  'conspiracy': 8250,
#  'vines': 12444,
#  'conjur': 7298,
#  'unbonnet': 18309,
#  'evermore': 5646,
#  'ecoutez': 15533,
#  'squares': 18279,
#  'treasure': 4124,
#  'afore': 6883,
#  'tomb': 3693,
#  'deracinate': 19844,
#  'mayest': 16987,
#  '##ec': 4289,
#  'admiring': 11029,
#  'warrior': 7539,
#  'discreet': 9443,
#  'idleness': 7301,
#  'injunctions': 18145,
#  'relieved': 8214,
#  'mandragora': 19439,
#  'ruth': 8184,
#  'orchard': 5351,
#  'nipp': 16179,
#  'dram': 6971,
#  '##si': 12460,
#  'dalmatians': 19706,
#  'incense': 8193,
#  'preserved': 7063,
#  'ast': 7663,
#  'confronted': 14666,
#  'fed': 4663,
#  'nods': 11404,
#  '##id': 159,
#  'delivers': 9490,
#  '##ir': 113,
#  'exhalation': 19329,
#  'dissemble': 7917,
#  'hardiness': 13907,
#  'pins': 9763,
#  'soil': 5071,
#  'exten': 9491,
#  'memories': 15112,
#  '##under': 2755,
#  '##ie': 303,
#  'desert': 3447,
#  'heavenly': 3682,
#  'minion': 6799,
#  'ili': 11299,
#  'harsh': 4712,
#  'sandy': 10302,
#  'towards': 3302,
#  'handker': 4257,
#  '##eers': 13999,
#  'moll': 14321,
#  '##unate': 6726,
#  'cased': 14833,
#  'helping': 10050,
#  'scandalized': 18896,
#  '##imes': 2491,
#  'faithful': 4579,
#  'lodging': 5677,
#  'latter': 6332,
#  'folly': 2991,
#  '##hold': 4296,
#  'unconquer': 19150,
#  'furrow': 12999,
#  'finder': 12852,
#  'disg': 2336,
#  'intent': 3873,
#  'purple': 7804,
#  'rhetoric': 10962,
#  '##ctar': 16736,
#  'requires': 7022,
#  'abhorring': 18466,
#  'prompting': 18713,
#  'cobbler': 18782,
#  '1': 9,
#  'admir': 4221,
#  'middle': 6287,
#  'exorc': 12629,
#  'unrec': 18733,
#  'dilated': 18722,
#  '##elon': 11504,
#  'walking': 7024,
#  '##zel': 11387,
#  'familiar': 4331,
#  'binds': 15292,
#  'mechanic': 13686,
#  '##chor': 4548,
#  'trenches': 10281,
#  '##iam': 1686,
#  'bes': 1833,
#  '##urse': 785,
#  'buttered': 18728,
#  'branded': 18807,
#  'clout': 9313,
#  'quench': 4833,
#  'debile': 18541,
#  'properer': 15157,
#  'footing': 7245,
#  'poisonous': 8217,
#  '##olt': 11418,
#  '##iless': 11469,
#  '##ifying': 11748,
#  'party': 4116,
#  'gav': 7106,
#  'yawn': 9777,
#  '##ouse': 725,
#  'vii': 849,
#  'buys': 8966,
#  'quaint': 6745,
#  'vane': 15124,
#  'ovid': 15922,
#  'jewel': 3562,
#  'outstretch': 13829,
#  'credent': 15089,
#  'zod': 16272,
#  '##ium': 8354,
#  'inflict': 17711,
#  'alex': 2249,
#  'aching': 14757,
#  'hitherwards': 19271,
#  'uprise': 19573,
#  'regent': 5938,
#  '##ggle': 15012,
#  'killingworth': 18658,
#  'denny': 8946,
#  'unne': 11526,
#  'hero': 1599,
#  '##uteous': 4433,
#  'xi': 16264,
#  'handiw': 14492,
#  'dispatch': 2844,
#  'caesar': 527,
#  '##ack': 991,
#  'dust': 3535,
#  'befri': 9588,
#  'strand': 12990,
#  '##quit': 14482,
#  'protectorship': 15211,
#  '##onis': 16447,
#  '##ose': 545,
#  'troubles': 6434,
#  'bloodless': 11640,
#  'taunts': 12175,
#  'tailor': 3977,
#  'vast': 5871,
#  'porch': 13193,
#  'fishmonger': 17799,
#  'terrestrial': 19855,
#  'chase': 4827,
#  'distribute': 19396,
#  'abergavenny': 5849,
#  'ingratitude': 6167,
#  'fou': 13881,
#  'inside': 10924,
#  'treason': 2533,
#  'larded': 12385,
#  '##charged': 11409,
#  'lie': 855,
#  'disput': 12965,
#  'clouts': 14282,
#  '##opa': 14406,
#  'hearty': 9949,
#  'anat': 9278,
#  'woolly': 17792,
#  '##ur': 128,
#  'dic': 11271,
#  'conjoin': 12639,
#  'brook': 2797,
#  'entrance': 6311,
#  'balth': 2428,
#  'throne': 3727,
#  'advise': 4314,
#  'seemeth': 9428,
#  'receiving': 10560,
#  'condemn': 3301,
#  'annual': 12140,
#  'steel': 3387,
#  'obl': 5728,
#  'cub': 12344,
#  'chang': 3105,
#  'strangers': 6458,
#  '##flow': 9079,
#  '##oly': 759,
#  'hotly': 12821,
#  'volumes': 12878,
#  'pitiless': 13127,
#  'vides': 16246,
#  '##ucon': 16300,
#  '##ieces': 16898,
#  'strength': 2416,
#  'murk': 17490,
#  'uncles': 10968,
#  'ptolemy': 15867,
#  'grumble': 17699,
#  'piping': 19060,
#  'boister': 7763,
#  '##ret': 1989,
#  '##osal': 16748,
#  '##el': 250,
#  'interchange': 8994,
#  'account': 3824,
#  'leav': 9856,
#  'derog': 11835,
#  'gobb': 3902,
#  'cop': 4662,
#  'corre': 4916,
#  'compl': 4169,
#  'calf': 4707,
#  'dol': 2849,
#  'hugg': 14663,
#  'reed': 14242,
#  'slanderer': 13243,
#  'misch': 14780,
#  'conferr': 15268,
#  '##leep': 3647,
#  'semblance': 6157,
#  '##ese': 355,
#  'sickness': 3732,
#  'truncheon': 11189,
#  '##ingham': 639,
#  'spoon': 11759,
#  'hazel': 12533,
#  '##ades': 1606,
#  'avail': 13212,
#  'amazon': 13231,
#  '##bearer': 15685,
#  '##eary': 11542,
#  'lawyers': 12148,
#  'nuncle': 6651,
#  'dungeons': 18663,
#  'gunpowder': 18816,
#  'furr': 17642,
#  'gabble': 15918,
#  'rotten': 4538,
#  'bachel': 6169,
#  'border': 19427,
#  'knowest': 6062,
#  'disf': 8458,
#  'dullard': 17896,
#  'wis': 2261,
#  'teach': 2179,
#  'thais': 2599,
#  'struggling': 19601,
#  'thrill': 15070,
#  '##cled': 11698,
#  'reechy': 19773,
#  'pirate': 7634,
#  'distraction': 8183,
#  'provide': 5309,
#  'attainted': 14654,
#  'reflect': 13192,
#  '##irt': 6032,
#  'tout': 13980,
#  'ever': 488,
#  'feverous': 15493,
#  'pilgrims': 15448,
#  'tapster': 7625,
#  'indirectly': 10311,
#  '##nel': 7395,
#  'trophies': 12798,
#  'relent': 6429,
#  'hann': 12372,
#  '##ish': 311,
#  'limitation': 18835,
#  'mislead': 12947,
#  'exhalations': 19330,
#  'wastes': 18096,
#  'heretics': 19147,
#  'churl': 10127,
#  'porn': 13956,
#  'chival': 8055,
#  'judgest': 17954,
#  'hum': 929,
#  'infinitely': 13356,
#  'nept': 5897,
#  'caps': 6084,
#  'consecrate': 10353,
#  'removing': 14618,
#  'bargains': 15472,
#  'john': 524,
#  '##aked': 2528,
#  '##ilis': 9299,
#  'instead': 7535,
#  '##ishop': 1722,
#  'importunity': 15067,
#  '##iro': 14121,
#  'rapine': 13382,
#  'urgent': 17828,
#  'pother': 17061,
#  'train': 2842,
#  'urged': 5032,
#  'pheeze': 19609,
#  'pitch': 4391,
#  'solitary': 17599,
#  'expertness': 19328,
#  'rector': 16693,
#  'innocent': 4027,
#  'saturnine': 6788,
#  'stop': 2303,
#  '##just': 5372,
#  'chooseth': 8222,
#  '##orter': 8766,
#  'outw': 11561,
#  'imperfect': 9065,
#  '##sey': 918,
#  'late': 1685,
#  'prouder': 9841,
#  'rudely': 11936,
#  'oven': 13947,
#  'vols': 4014,
#  'instruments': 5831,
#  'erp': 5913,
#  'philomel': 8931,
#  'waste': 4090,
#  'grecians': 10244,
#  'royalties': 11132,
#  'wrestle': 10251,
#  'sage': 12773,
#  'armipotent': 14534,
#  '##idian': 14197,
#  'combination': 15220,
#  'usher': 8852,
#  'trumpery': 19786,
#  'spots': 8854,
#  'corrigible': 19808,
#  'fustian': 15774,
#  'endue': 17332,
#  'burdened': 18741,
#  'diminutives': 19693,
#  'neanmo': 16772,
#  'lads': 5811,
#  '##omed': 1740,
#  'enforce': 4414,
#  'graved': 17081,
#  'who': 348,
#  'apparel': 4519,
#  'infer': 6416,
#  'exercise': 6474,
#  'unsounded': 18186,
#  'cyprus': 5134,
#  '##hand': 10489,
#  'rogue': 3196,
#  'laughter': 5323,
#  'lessen': 10797,
#  'has': 1138,
#  'rear': 5892,
#  '##wal': 9780,
#  'kil': 13921,
#  ...}

# %% [markdown]
# ### Tokenize dataset
# * Use the tokenizer and vocabulary to convert the dataset into a sequence of integers.

# %%
def data_process(
    data_list: List[str],
    tokenizer: Callable,
) -> Tensor:
    """Converts raw text into a flat Tensor.

    Args:
        data_list (List[str]): A list of raw text data.
        tokenizer (Callable): An English tokenizer.

    Returns:
        Tensor: A flat Tensor containing the numeric form of the flatten text.
    """
    data = [torch.tensor(tokenizer.encode(item).ids, dtype=torch.long)
            for item in data_list]
    return torch.cat(tuple(filter(lambda t: t.numel() > 0, data)))

# %%
# Here we convert the raw training and validation data
# into tensors of token IDs.
training_data = data_process(training_list, tokenizer)
validation_data = data_process(validation_list, tokenizer)
print(f'Quick look at the numericalized data {training_data}.')
print(f'The length of the training_data is {len(training_data)}.')
print(f'The length of the validation_data is {len(validation_data)}.')
# Out:
# Quick look at the numericalized data tensor([ 3197,   775,    18,  ...,    18,   543, 19863]).
# The length of the training_data is 1338877.
# The length of the validation_data is 79222.

# %% [markdown]
# ## Batchify dataset
# - Create batches out of the long list of number
# - This allows for parallel computation during training
# - Drawback being the relationship between the batches are not learned
#
# See this link for more detail: https://pytorch.org/tutorials/beginner/transformer_tutorial.html#load-and-batch-data

# %%
def batchify(data: Tensor, bsz: int) -> Tensor:
    """Divides the data into bsz separate sequences, removing extra elements
    that wouldn't cleanly fit.

    Args:
        data: Tensor, shape [N]
        bsz: int, batch size

    Returns:
        Tensor of shape [N // bsz, bsz]
    """
    seq_len = data.size(0) // bsz
    data = data[:seq_len * bsz]
    data = data.view(bsz, seq_len).t().contiguous()
    return data.to(DEVICE)

# %% [markdown]
# ## Generate input and target sequence
# - Grab an input sequence with length `seq_len` from the batchify data starting at index `i`
# - The target sequence also has the same length `seq_len` but the starting index is `i+1`
#
# See this link for more detail: https://pytorch.org/tutorials/beginner/transformer_tutorial.html#functions-to-generate-input-and-target-sequence

# %%
def get_batch(source: Tensor, i: int, bptt: int) -> Tuple[Tensor, Tensor]:
    """
    Args:
        source: Tensor, shape [full_seq_len, batch_size]
        i: int

    Returns:
        tuple (data, target), where data has shape [seq_len, batch_size] and
        target has shape [seq_len * batch_size]
    """
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].reshape(-1)
    return data, target

# %%
len(batchify(training_data, 64))
# Out:
# 20919

# %%
# Example batch drawn from the data and decoded
# to show what the model will be predicting against
def print_example_batch():
    example_batch = batchify(training_data, 2)
    example_data, example_targets = get_batch(example_batch, 6485, 55)
    print(f"Example data: {example_data.t()}")
    print(f"Example targets: {example_targets}")
    print(
        f"=== Example data[0] decoded ===\n{tokenizer.decode(example_data[:, 0].tolist())}"
    )
    print(
        f"=== Example data[1] decoded ===\n{tokenizer.decode(example_data[:, 1].tolist())}"
    )
    print(
        f"=== Example targets decoded ===\n{tokenizer.decode(example_targets.tolist()[:20])}"
    )


print_example_batch()

print(tokenizer.decode(batchify(training_data, 2).to("cpu")[:, 0].tolist()[:100]))
# Out:
# Example data: tensor([[  350,    18,   175,   686,   169,  2235,  1356,   416,   115,  4006,
#          19863,   350,    18,   234,  6987,     5,  2927,     5, 13726,  9542,
#             19, 19863,  2868,    18,   102,  1047,   119,   222,   167,  2545,
#           2293,   160,   835,    19, 19863,   350,    18,   102,   256,     5,
#            130,   560,   414,  2863,   414,   835,     7, 19863,   350,    18,
#            343,   177,    30, 15120,   256],
#         [ 1291,   104,   507,     7, 19863,  1633,    18,  2084,  5170,  1574,
#              5,   239,   295,  1083,    22,  6366,     1, 19863,   173,    18,
#           1627,   776,    99,  4068, 19863,  1581,    18,   180,    93,  1960,
#          19863,  1581,    18,  1240,  1371,    18, 19863,  1581,    18,    30,
#              2,   298,  6995, 19863,  1581,    18,   102,   160,  1096,     5,
#          19863,  1581,    18,   373,  3344]], device='cuda:0')
# Example targets: tensor([   18,   104,   175,   507,   686,     7,   169, 19863,  2235,  1633,
#          1356,    18,   416,  2084,   115,  5170,  4006,  1574, 19863,     5,
#           350,   239,    18,   295,   234,  1083,  6987,    22,     5,  6366,
#          2927,     1,     5, 19863, 13726,   173,  9542,    18,    19,  1627,
#         19863,   776,  2868,    99,    18,  4068,   102, 19863,  1047,  1581,
#           119,    18,   222,   180,   167,    93,  2545,  1960,  2293, 19863,
#           160,  1581,   835,    18,    19,  1240, 19863,  1371,   350,    18,
#            18, 19863,   102,  1581,   256,    18,     5,    30,   130,     2,
#           560,   298,   414,  6995,  2863, 19863,   414,  1581,   835,    18,
#             7,   102, 19863,   160,   350,  1096,    18,     5,   343, 19863,
#           177,  1581,    30,    18, 15120,   373,   256,  3344,    19,     5],
#        device='cuda:0')
# === Example data[0] decoded ===
# gloucester : but thus his simple truth must be abused
#  gloucester : by silken, sly, insinuating jacks?
#  rivers : to whom in all this presence speaks your grace?
#  gloucester : to thee, that hast nor honesty nor grace.
#  gloucester : when have i injured thee
# === Example data[1] decoded ===
# break of day.
#  hermia : heavens shield lysander, if they mean a fray!
#  narrator : lies down and sleeps
#  puck : on the ground
#  puck : sleep sound :
#  puck : i ' ll apply
#  puck : to your eye,
#  puck : gentle lover
# === Example targets decoded ===
# : of but day thus. his
#  simple hermia truth : must heavens be shield abused lysander
# ,
# ''' play : richard iii '''
#  narrator : act i
#  narrator : scene i. london. a street.
#  narrator : enter gloucester, solus
#  gloucester : now is the winter of our discontent
#  gloucester : made glorious summer by this sun of york,
#  gloucester : and all the clouds that lour ' d upon our house
#  gloucester : in the deep bosom of the ocean buried.
#  gloucester : now are our brows bound with victorious wreaths,
#  gloucester : our bruised arms hung up for monuments

# %% [markdown]
# ## Create recurrent neural network model
# A recurrent neural network with an embedding layer, one or more recurrent layers, and a linear layer.
#
# We use this `RecurrentModel` class to describe the behavior of the embedding and output layers, which are the same no matter which recurrent unit we use. We then pass the recurrent unit as a parameter to the `RecurrentModel` constructor to describe the behavior of the recurrent layers. This lets us easily create models with different recurrent units to compare their performance.

# %%
class RecurrentModel(Module):
    """The recurrent neural network."""

    # __init__ is the constructor.
    # It sets up new instances of the class.
    def __init__(
        self,
        vocab_size: int,
        recurrent_module: Union[RNN, LSTM, GRU],
    ) -> None:
        """Initialize the recurrent neural network.

        Note: For this model architecure, if the number of layers is greater
        than 1, then embedding size and hidden size must be equal.

        Args:
            vocab_size (int): The number of vocabulary in the dataset.
            embedding_dim (int): The dimension of the embedding output.
            hidden_size (int): The size of the recurrent unit's hidden state.
            num_layers (int): The number of recurrent unit layers.

        Raises:
            ValueError: If the number of layers is greater than 1 and the
            embedding size is not equal to the hidden size.
        """
        # First, we call the superclass constructor
        # to give PyTorch a chance to set up the
        # parts of the object it needs to.
        super().__init__()

        # num_layers is how many layers the recurrent unit has.
        num_layers = recurrent_module.num_layers

        # hidden_size is the size of the hidden state of the recurrent unit.
        hidden_size = recurrent_module.hidden_size

        # embedding_dim is the size of the embedding output.
        embedding_dim = recurrent_module.input_size

        if (num_layers > 1) and (hidden_size != embedding_dim):
            raise ValueError(
                "When the number of layers is greater than 1, the embedding "
                "size and hidden size must be equal."
            )

        # The embedding layer turns the token IDs into embedding vectors.
        # This is a matrix of size [vocab_size, embedding_dim].
        # Each row of the matrix corresponds to one token in the vocabulary,
        #  providing a sort of "meaning in isolation" for that token.
        # The embedding layer is a trainable part of the model,
        #  so it will be updated during training.
        # The values start out initialized randomly.
        self.embedding = Embedding(
            num_embeddings=vocab_size, embedding_dim=embedding_dim
        )

        # The recurrent module is the main part of the model.
        # It takes in a sequence of embedding vectors
        #  and spreads information across the sequence.
        self.rnn = recurrent_module

        # The linear layer is the output layer of the model.
        # It takes in the final embedding vector from the
        #  recurrent module and outputs a vector of size [vocab_size].
        # This vector contains a score for each token in the vocabulary.
        # The token with the highest score is the one the model predicts
        #  as the next token, so the model will try to make the score
        #  for the correct token as high as possible.
        self.linear = Linear(hidden_size, vocab_size)

    # The forward method is called when we pass data through the model.
    def forward(
        self,
        x: Tensor,
        prev_state: Optional[Union[Tensor, Tuple[Tensor, Tensor]]],
    ) -> Tuple[Tensor, Union[Tensor, Tuple[Tensor, Tensor]]]:
        """Pass the a batch of data through the recurrent neural network model
        along with the previous state.

        Args:
            x (Tensor): The batch of data.
            prev_states (Tensor): The previous states of the recurrent units.

        Returns:
            Tuple[Tensor, Tensor]: The logits and hidden states.
        """

        # Embed the input tokens using the embedding layer
        embedded = self.embedding(x)

        # Pass the embedded input tokens into the recurrent module along with the previous state
        output, state = self.rnn(embedded, prev_state)

        # Pass the final embedding vector into the linear layer to get the logits
        logits = self.linear(output)

        # Return the logits and the final states
        return logits, state


    def detach_state_(self, states: Union[Tensor, Tuple[Tensor, Tensor]]) -> None:
        """Detach the state of the recurrent units.

        This function is used to make sure the model doesn't try to backpropagate
        through the entire history of the sequence, as our computers can't
        handle that much data.

        Args:
            states (Union[Tensor, Tuple[Tensor, Tensor]]): The states of the
            recurrent units.
        """
        if isinstance(states, Tensor):
            states.detach_()
        elif isinstance(states, tuple):
            for state in states:
                state.detach_()

# %% [markdown]
# ## Define training loss
# The loss function is the negative log likelihood loss since we are doing classification.
#
# The classification problem is, based on the previous words, what is the next word.
#
# Our target classes are all the words in the vocabulary.

# %%
criterion = CrossEntropyLoss()

# %% [markdown]
# ## Define training and evaluation functions
# - `train_epoch` trains the model for one epoch
# - `evaluate` evaluates the model on the validation set
# - `train_run` trains the model for all `EPOCHS` epochs and prints as it goes

# %%
def train_epoch(model: RecurrentModel, optimizer: torch.optim.Optimizer, train_data: Tensor, parameters:Parameters) -> Tuple[float,float]:
    """Training function for our recurrent model.

    Args:
        model (RecurrentModel): The model to train.
        train_data (Tensor): Batchified training data.
    """
    # Turn on training mode which enables training-specific
    # layer functionality (e.g. dropout)
    model.train()

    # Keep track of the loss as we go
    total_loss: float = 0.

    # Determine how many steps we'll need to cover the whole dataset
    num_batches: int = len(train_data) // parameters.BPTT

    # Keep track of the hidden state between batches.
    state = None

    # For each of our batches
    for i in range(0, train_data.size(0) - 1, parameters.BPTT):
        # Throw away gradients from previous step
        optimizer.zero_grad()

        # Get our input and target batches
        data, targets = get_batch(train_data, i, parameters.BPTT)

        # Evaluate the model to get logits and the new hidden state
        output, state = model(data, state)

        # Compute the loss
        loss = criterion(output.view(-1, vocab_size), targets)

        # Make sure the state does not carry gradients
        # between batches so we avoid a runaway memory leak
        model.detach_state_(state)

        # Compute gradients
        loss.backward()

        # Clip the gradients to avoid exploding gradients
        # (Ask us TAs if you're curious why this is necessary)
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)

        # Update the parameters
        optimizer.step()

        # Keep track of the loss
        total_loss += loss.item()

    # Return the average loss across batches
    cur_loss = total_loss / num_batches
    # and the perplexity
    ppl = math.exp(cur_loss)
    return cur_loss, ppl

# %%
def evaluate(model: RecurrentModel, val_data: Tensor, parameters: Parameters) -> Tuple[float, float]:
    """Evaluate the perplexity of the model on the validation data.

    Args:
        model (RecurrentModel): The model to evaluate.
        val_data (Tensor): Batchified validation data.

    Returns:
        float: The perplexity of the model on the validation data.
    """
    # Turn on evaluation mode which disables
    # training-specific functionality (e.g. dropout)
    model.eval()

    # Keep track of the loss as we go
    total_loss: float = 0.

    # Determine how many steps we'll need to cover the whole dataset
    num_batches: int = len(val_data) // parameters.BPTT

    # Keep track of the hidden state between batches.
    state = None
    with torch.no_grad(): # No need to track gradients here, since we're not training
        for i in range(0, val_data.size(0) - 1, parameters.BPTT):
            # Get our input and target batches
            data, targets = get_batch(val_data, i, parameters.BPTT)

            # Evaluate the model to get logits and the new hidden state
            output, state = model(data, state)

            # Compute the loss
            loss = criterion(output.view(-1, vocab_size), targets)
            total_loss += loss.item()

    # Return the average loss across batches
    cur_loss = total_loss / num_batches
    # and the perplexity
    ppl = math.exp(cur_loss)
    return cur_loss, ppl

# %%
def train_run(model: RecurrentModel, train_data: Tensor, validation_data: Tensor, parameters: Parameters, verbose: bool = True) ->None:
    """Train a model for NUM_EPOCHS epochs.

    Args:
        model (RecurrentModel): The model to train.
        train_data (Tensor): Batchified training data.
    """
    # Here we define an optimizer and scheduler to use for training.
    # An optimizer adjusts the parameters of the model based on the loss
    # and the gradients of the parameters with respect to the loss.

    # Adam is a popular optimizer that tends to work well in practice.
    # optimizer = torch.optim.Adam(model.parameters(), lr=parameters.LR) # Set LR to about 0.005 to start

    # AdamW corrects a minor flaw in the original Adam implementation
    # allowing it to converge slightly better.
    optimizer = torch.optim.AdamW(model.parameters(), lr=parameters.LR) # Set LR to about 0.01

    # SGD is the simple stochastic gradient descent algorithm,
    # implemented as LR * gradient.
    # Notably, the RNNs shown here need a strong learning rate to
    # even begin to move the loss, so we start with a high LR.
    # optimizer = torch.optim.SGD(model.parameters(), lr=parameters.LR) # Set LR to about 10.0 to start 

    # The scheduler adjusts the learning rate over time.
    # Here we use a scheduler that decreases the learning rate
    # by a factor of 0.5 if the training loss doesn't decrease
    # for two epochs in a row.
    # This makes sure that the model can converge down into a
    # minimum once it finds one, instead of bouncing around.
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.5, patience=1, threshold=1e-3)

    # Train for NUM_EPOCHS epochs
    for epoch in range(1,parameters.EPOCHS+1,1):
        if verbose:
            # Print out an initial message stating the epoch number
            # and learning rate
            lrs = [group['lr'] for group in optimizer.param_groups]
            lr = lrs[0] if len(lrs) > 0 else -1
            # The end='' argument tells Python not to print a newline
            # so we can extend this row with more information
            # as we compute it.
            print(f'| epoch {epoch:3d} | lr {lr:03.3f} | ', end='')

        # Train for one epoch
        loss, ppl = train_epoch(model, optimizer, train_data, parameters)

        # Update the learning rate
        scheduler.step(loss)
        # Note that we can move this line after the validation step
        # if we want to update the learning rate based on the val
        # loss instead of the training loss.

        if verbose:
            # Update the printed row with the training loss and perplexity
            # so that the user knows the training step completed and that
            # we're now evaluating on the validation set.
            print(f'train loss {loss:5.2f} | train ppl {ppl:8.2f} | ', end='')

        # Evaluate on the validation set
        val_loss, val_ppl = evaluate(model, validation_data, parameters)

        if verbose:
            # Update the printed row with the validation loss and perplexity
            print(f'val loss {val_loss:5.2f} | val ppl {val_ppl:8.2f} |')
            # We no longer have the end='' argument, so this completes the line.

# %%
def create_model(
    vocab_size: int,
    parameters: Parameters,
    model_type: Callable[..., Union[RNN, LSTM, GRU]],
) -> RecurrentModel:
    """Create a recurrent model.

    Args:
        vocab_size (int): The number of vocabulary in the dataset.
        parameters (Parameters): The model parameters.
        model_type (Callable[..., Union[RNN, LSTM, GRU]]): The type of recurrent
            model to create.

    Returns:
        RecurrentModel: The recurrent model.
    """
    # Create the model
    # We've split the model into two pieces:
    # 1. The RecurrentModel class, which defines the overall model architecture
    #    including the embedding and output layer
    # 2. The RNN, LSTM, or GRU class, which defines the recurrent unit
    #    that will be used inside the model.
    # This allows us to easily swap out different recurrent units
    # without having to rewrite the whole model's code
    # across multiple notebooks or cells.
    return RecurrentModel(
        vocab_size=vocab_size,
        recurrent_module=model_type(
            input_size=parameters.EMBEDDING_DIM,
            hidden_size=parameters.HIDDEN_DIM,
            num_layers=parameters.NUM_LAYERS,
        ),
    ).to(DEVICE)

def train_model(
    model: RecurrentModel,
    unbatched_train_data: Tensor,
    unbatched_validation_data: Tensor,
    parameters: Parameters,
    verbose: bool = True,
) -> None:
    if verbose:
        print(f'The shape of the training data is {training_data.shape}.')
    batched_training_data = batchify(unbatched_train_data, parameters.BATCH_SIZE)
    if verbose:
        print(f'The shape of the batched training data is {batched_training_data.shape}.')
        print(f'The shape of the validation data is {validation_data.shape}.')
    batched_validation_data = batchify(unbatched_validation_data, parameters.BATCH_SIZE)
    if verbose:
        print(f'The shape of the batched validation data is {batched_validation_data.shape}.')

    train_run(model, batched_training_data, batched_validation_data, parameters, verbose)
    return model
    

def create_and_train_model(
    vocab_size: int,
    parameters: Parameters,
    model_type: Callable[..., Union[RNN, LSTM, GRU]],
    unbatched_train_data: Tensor,
    unbatched_validation_data: Tensor,
    verbose: bool = True,
) -> RecurrentModel:
    """Create and train a recurrent model.

    Args:
        vocab_size (int): The number of vocabulary in the dataset.
        parameters (Parameters): The model parameters.
        model_type (Callable[..., Union[RNN, LSTM, GRU]]): The type of recurrent
            model to create.
        train_data (Tensor): Unbatched training data.

    Returns:
        RecurrentModel: The trained recurrent model.
    """
    model = create_model(vocab_size, parameters, model_type)
    model.to(DEVICE)

    train_model(model, unbatched_train_data, unbatched_validation_data, parameters, verbose)
    return model

# %% [markdown]
# ## Run model-building experiments

# %%
parameters1 = Parameters(
    BATCH_SIZE=16,
    BPTT=50,
    LR=0.01,
    EPOCHS=30,
    EMBEDDING_DIM=16,
    HIDDEN_DIM=16,
    NUM_LAYERS=3,
)
model1 = create_model(
    vocab_size=vocab_size,
    parameters=parameters1,
    model_type=RNN,
)
train_model(
    model=model1,
    unbatched_train_data=training_data,
    unbatched_validation_data=validation_data,
    parameters=parameters1,
    verbose=True,
)
# Out:
# The shape of the training data is torch.Size([1338877]).
# The shape of the batched training data is torch.Size([83679, 16]).
# The shape of the validation data is torch.Size([79222]).
# The shape of the batched validation data is torch.Size([4951, 16]).
# | epoch   1 | lr 0.010 | train loss  5.13 | train ppl   168.46 | val loss  5.89 | val ppl   363.13 |
# | epoch   2 | lr 0.010 | train loss  4.66 | train ppl   105.49 | val loss  5.75 | val ppl   315.52 |
# | epoch   3 | lr 0.010 | train loss  4.57 | train ppl    96.27 | val loss  5.78 | val ppl   325.16 |
# | epoch   4 | lr 0.010 | train loss  4.52 | train ppl    91.59 | val loss  5.64 | val ppl   281.76 |
# | epoch   5 | lr 0.010 | train loss  4.48 | train ppl    88.44 | val loss  5.60 | val ppl   271.52 |
# | epoch   6 | lr 0.010 | train loss  4.46 | train ppl    86.14 | val loss  5.63 | val ppl   279.69 |
# | epoch   7 | lr 0.010 | train loss  4.44 | train ppl    84.40 | val loss  5.70 | val ppl   298.45 |
# | epoch   8 | lr 0.010 | train loss  4.42 | train ppl    82.93 | val loss  5.64 | val ppl   281.96 |
# | epoch   9 | lr 0.010 | train loss  4.40 | train ppl    81.79 | val loss  5.73 | val ppl   308.91 |
# | epoch  10 | lr 0.010 | train loss  4.40 | train ppl    81.08 | val loss  5.67 | val ppl   291.10 |
# | epoch  11 | lr 0.010 |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 15
#       1 parameters1 = Parameters(
#       2     BATCH_SIZE=16,
#       3     BPTT=50,
#    (...)
#       8     NUM_LAYERS=3,
#       9 )
#      10 model1 = create_model(
#      11     vocab_size=vocab_size,
#      12     parameters=parameters1,
#      13     model_type=RNN,
#      14 )
# ---> 15 train_model(
#      16     model=model1,
#      17     unbatched_train_data=training_data,
#      18     unbatched_validation_data=validation_data,
#      19     parameters=parameters1,
#      20     verbose=True,
#      21 )
#
# Cell In[22], line 52, in train_model(model, unbatched_train_data, unbatched_validation_data, parameters, verbose)
#      49 if verbose:
#      50     print(f'The shape of the batched validation data is {batched_validation_data.shape}.')
# ---> 52 train_run(model, batched_training_data, batched_validation_data, parameters, verbose)
#      53 return model
#
# Cell In[21], line 46, in train_run(model, train_data, validation_data, parameters, verbose)
#      43     print(f'| epoch {epoch:3d} | lr {lr:03.3f} | ', end='')
#      45 # Train for one epoch
# ---> 46 loss, ppl = train_epoch(model, optimizer, train_data, parameters)
#      48 # Update the learning rate
#      49 scheduler.step(loss)
#
# Cell In[19], line 50, in train_epoch(model, optimizer, train_data, parameters)
#      47     optimizer.step()
#      49     # Keep track of the loss
# ---> 50     total_loss += loss.item()
#      52 # Return the average loss across batches
#      53 cur_loss = total_loss / num_batches
#
# KeyboardInterrupt:

# %% [markdown]
# ## Test model by generating text

# %%
def generate_text(
    tokenizer: Tokenizer,
    model: RecurrentModel,
    input_text: str,
    num_tokens_to_generate: int,
    by_prob: bool = False,
) -> str:
    """Input a text and use the model generate the next `n` words.

    Args:
        tokenizer (Tokenizer): The tokenizer used in training.
        model (RNNModel): A trained recurrent neural network model.
        text (str): A string of text to generate the text off of.
        num_words (int, optional): The number of words to generate.
            Defaults to 10.
        by_prob (bool, optional): If `True`, words are randomly generated
            based on probability. If `False`, words are generated based on
            highest probability. Defaults to False.

    Returns:
        str: Generated text string.
    """

    # Set the model to evaluation mode (no Dropout and the like)
    model.eval()

    with torch.no_grad(): # Disable gradient calculation because we won't use it

        # Process our input text
        data = data_process([input_text], tokenizer)
        # Turn it into a batch for the model
        x = data.reshape((-1, 1)).to(DEVICE)

        state = None # Start with a blank state
        output_tokens = [] # Keep track of the generated tokens
        for _ in range(num_tokens_to_generate):
            # Get the model's predicted next token
            y_pred, state = model(x, state)
            # We only care about the last token's predictions
            last_word_logits = y_pred[-1][0]

            # If we're generating by probability, we'll randomly choose a word
            if by_prob:
                # Normalize the logits so they form a probability distribution
                p = (
                    torch.nn.functional.softmax(last_word_logits, dim=0)
                    .cpu()
                    .numpy()
                )
                # Randomly choose the next word based on the probability
                word_index = np.random.choice(len(last_word_logits), p=p)
            else:
                # Otherwise, we'll just choose the word with the highest probability
                word_index = torch.argmax(last_word_logits)

            # Add the generated word to our output
            output_tokens.append(word_index)

            # Add the generated word as the next input to the model
            x = torch.tensor([word_index]).reshape(1, 1).to(DEVICE)

    # Decode the generated tokens and return the result
    return tokenizer.decode(output_tokens)

# %%
print(generate_text(
    tokenizer,
    model1,
    "You're so fucking gorgeous baby",
    100,
    by_prob=True,
))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(generate_text(
#       2     tokenizer,
#       3     model1,
#       4     "You're so fucking gorgeous baby",
#       5     100,
#       6     by_prob=True,
#       7 ))
#
# NameError: name 'generate_text' is not defined
